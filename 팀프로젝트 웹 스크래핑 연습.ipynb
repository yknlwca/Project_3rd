# %%
from selenium import webdriver
import urllib.request
from bs4 import BeautifulSoup
import os

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.google.com/?hl=ko')

# %%
search=driver.find_elements('css selector','#APjFqb')[0]

# %%
search.send_keys('이미지')

# %%
search.submit()

# %%
first=driver.find_elements("css selector",'#hdtb-msb > div:nth-child(1) > div > div:nth-child(2) > a')[0]
first.click()

# %%
html=driver.page_source
html
# Out:
# '<html lang="ko" dir="ltr" itemscope="" itemtype="http://schema.org/SearchResultsPage"><head><script src="https://www.gstatic.com/_/mss/boq-search/_/js/k=boq-search.VisualFrontendUi.ko.okj0REJ4Qxk.es5.O/ck=boq-search.VisualFrontendUi.UYdGgmFjZE0.L.B1.O/am=EAAAQAAAAAAAAAAAAAAAAAZ84P8DsJ8aAAJQX_r_______9XESSm5z_CAAJ0bAD4yA0AQBAAAwCOQhwMgMgEgNAFRABQ1ED3VgEgALyBRwkgABIAgAAKAAAAAQAI_REMBP4BAgAAgDMCAgQAAAAguOYBAwIAAAAAAAAAAAAABFUMAAAAAAAAAAAAAAHQJA/d=1/exm=A7fCU,BVgquf,COQbmf,CnSW2d,D8Qs1c,DMqaCe,DPreE,Dggaob,EEDORb,EFQ78c,EMKV5d,EU1dwe,EVgswe,EbPKJf,Fdd8nd,GFartf,Gu8rrc,HU2IR,I6YDgd,IOCaLe,IZT63,JNoxi,KG2eXe,KUM7Z,L1AAkb,L8KGxe,LEikZe,LUacLb,LmbeUd,MI6k7c,Mimmmd,Mlhmy,MpJwZc,Nlraib,NwH0H,O1Gjze,O6y8ed,ONqfcd,OTA3Ae,ObWLec,OmgaI,OvCQqe,P9vDhc,PrPYRd,QIhFr,Qg94gd,RMhBfe,Rr5NOe,RudZ1,S1avQ,S9MdGb,SGpRce,SM1lmd,SZXsif,SdcwHb,SpsfSb,SyIYXd,SzpDQc,T8nZfb,TZG3Xc,U0aPgd,UUJqVe,UXfCNd,Uas9Hd,Ulmmrd,V3dDOb,V8bRj,VwDzFe,WO9ee,WVCDgf,Wf0Cmd,WlNQGd,Wq6lxf,XEbUte,XJI8jf,XVMNvd,XVQ52e,Xn5N7c,Xt0JT,YsST1
# ...

# %%
soup=BeautifulSoup(html,'html.parser')

# %%
soup.select('src')
# Out:
# []

# %%
img=driver.find_elements('css selector','#islrg > div.islrc > div:nth-child(2) > a.FRuiCf.islib.nfEiy > div.fR600b.islir > img')[0]
img.click()

# %%
driver.find_elements('css selector','#Sva75c > div.A8mJGd.NDuZHe.CMiV2d.OGftbe-N7Eqid-H9tDt > div.dFMRD > div.AQyBn > div.tvh9oe.BIB1wf.hVa2Fd > c-wiz > div > div > div > div.v6bUne > div.p7sI2.PUxBg > a > img.sFlh5c.pT0Scc.iPVvYb')[0]
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="3b93b6573ad7a6ff0e95c247fc1cc468", element="579946CCA51FFE898B2D68CFBC6935B6_element_189")>

# %%
urllib.request.urlretrieve('data:image/png;base64,...','이미지.jpg')
# Out:
# ('이미지.jpg', <email.message.Message at 0x1f60428e3d0>)

# %%
<img src="data:image/png;base64,..." data-deferred="1" class="rg_i Q4LuWd" jsname="Q4LuWd" width="205" height="205" alt="토끼 캐릭터 일러스트 ai 이미지 다운로드 - Urbanbrush" data-iml="725.1000000014901" data-atf="true">
# Out:
#   Cell In[42], line 1
#     <img src="data:image/png;base64,..." data-deferred="1" class="rg_i Q4LuWd" jsname="Q4LuWd" width="205" height="205" alt="토끼 캐릭터 일러스트 ai 이미지 다운로드 - Urbanbrush" data-iml="725.1000000014901" data-atf="true">
#     ^
# SyntaxError: invalid syntax

# %%
<img src="data:image/jpeg;base64,..." data-deferred="1" class="rg_i Q4LuWd" jsname="Q4LuWd" width="299" height="169" alt="Photosho이미지 크기를 변경하는 방법! 일괄 변경도 가능" data-iml="725.1999999992549" data-atf="true">

# %%
urllib.request.urlretrieve("data:image/jpeg;base64,...",'test.jpg')
# Out:
# ('test.jpg', <email.message.Message at 0x1fb5d902950>)

# %%
img_tags = soup.select('img.rg_i.Q4LuWd')

# %%
len(img_tags)
# Out:
# 50

# %%
import urllib.request
from bs4 import BeautifulSoup


for i, img_tag in enumerate(soup.select('img.rg_i.Q4LuWd')):
    try:
        if 'data-src' in img_tag.attrs:
            img_url = img_tag['data-src']
        else:
            img_url = img_tag['src']

        urllib.request.urlretrieve(img_url, f'{i + 1}.jpg')
        print(f"Image {i + 1} downloaded successfully.")
    except Exception as e:
        print(f"Error downloading image {i + 1}: {str(e)}")
# Out:
# Image 1 downloaded successfully.
# Image 2 downloaded successfully.
# Image 3 downloaded successfully.
# Image 4 downloaded successfully.
# Image 5 downloaded successfully.
# Image 6 downloaded successfully.
# Image 7 downloaded successfully.
# Image 8 downloaded successfully.
# Image 9 downloaded successfully.
# Image 10 downloaded successfully.
# Image 11 downloaded successfully.
# Image 12 downloaded successfully.
# Image 13 downloaded successfully.
# Image 14 downloaded successfully.
# Image 15 downloaded successfully.
# Image 16 downloaded successfully.
# Image 17 downloaded successfully.
# Image 18 downloaded successfully.
# Image 19 downloaded successfully.
# Image 20 downloaded successfully.
# Image 21 downloaded successfully.
# Image 22 downloaded successfully.
# Image 23 downloaded successfully.
# Image 24 downloaded successfully.
# Image 25 downloaded successfully.
# Image 26 downloaded successfully.
# Image 27 downloaded successfully.
# Image 28 downloaded successfully.
# ...

# %%
urllib.request.urlretrieve(img_tags[49]['data-src'],'d.jpg')
# Out:
# ('d.jpg', <http.client.HTTPMessage at 0x1f604e64d90>)

# %%
img_tags[26]['data-src']
# Out:
# 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTmy6IFa7_C1Je47STTW9dD3CO3di2RGMJjKg&usqp=CAU'
